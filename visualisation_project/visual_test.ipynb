# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv("lung_cancer_examples.csv")
df.head()
# Out:
#      Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0    John         Wick   35       3      5       4       1
# 1    John  Constantine   27      20      2       5       1
# 2  Camela     Anderson   30       0      5       2       0
# 3    Alex       Telles   28       0      8       1       0
# 4   Diego     Maradona   68       4      5       6       1

# %%
df.tail()
# Out:
#          Name   Surname  Age  Smokes  AreaQ  Alkhol  Result
# 54    Ernest   Borgnine   26      13      6       1       0
# 55      Alec   Guinness   77      20      5       4       1
# 56  Charlton     Heston   75      15      3       5       1
# 57   Gregory       Peck   43      30      3       8       1
# 58    Sidney    Poitier   51      25      9       0       0

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#              Age     Smokes      AreaQ     Alkhol     Result
# count  59.000000  59.000000  59.000000  59.000000  59.000000
# mean   42.627119  15.067797   5.203390   3.237288   0.474576
# std    16.235230   7.984607   2.461984   2.380517   0.503640
# min    18.000000   0.000000   1.000000   0.000000   0.000000
# 25%    29.000000  10.000000   3.000000   1.000000   0.000000
# 50%    39.000000  15.000000   5.000000   3.000000   0.000000
# 75%    55.000000  20.000000   7.500000   5.000000   1.000000
# max    77.000000  34.000000  10.000000   8.000000   1.000000

# %%
df_res = df.groupby("Result")
df_res.head()
# Out:
#          Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0        John         Wick   35       3      5       4       1
# 1        John  Constantine   27      20      2       5       1
# 2      Camela     Anderson   30       0      5       2       0
# 3        Alex       Telles   28       0      8       1       0
# 4       Diego     Maradona   68       4      5       6       1
# 5   Cristiano      Ronaldo   34       0     10       0       0
# 6      Mihail          Tal   58      15     10       0       0
# 7       Kathy        Bates   22      12      5       2       0
# 9         Ray      Milland   52      18      4       5       1
# 13       Jane        Wyman   28      20      2       8       1

# %%
df_res.describe()
# Out:
#          Age                                                       Smokes  \
#        count       mean        std   min    25%   50%    75%   max  count
# Result
# 0       31.0  32.870968   9.745912  18.0  25.50  33.0  38.00  58.0   31.0
# 1       28.0  53.428571  15.179002  26.0  42.75  55.0  62.25  77.0   28.0
#
#                    ... AreaQ       Alkhol                                     \
#              mean  ...   75%   max  count      mean       std  min  25%  50%
# Result             ...
# 0       12.258065  ...   8.0  10.0   31.0  1.419355  1.118755  0.0  0.5  1.0
# 1       18.178571  ...   5.0   7.0   28.0  5.250000  1.669442  3.0  4.0  5.0
#
#
#         75%  max
# Result
# 0       2.0  4.0
# 1       6.0  8.0
#
# [2 rows x 32 columns]

# %%
df_res.mean()
# Out:
#               Age     Smokes     AreaQ    Alkhol
# Result
# 0       32.870968  12.258065  6.935484  1.419355
# 1       53.428571  18.178571  3.285714  5.250000

# %%
sns.barplot(data=df, x="Result", y="Smokes")
plt.xlabel("Has Cancer")
plt.ylabel("Average Amount of Cigarettes a Day")
plt.title("")
# Out:
# <AxesSubplot:xlabel='Result', ylabel='Smokes'>

# %%
sns.barplot(data=df, x="Result", y="Alkhol")
# Out:
# <AxesSubplot:xlabel='Result', ylabel='Alkhol'>
