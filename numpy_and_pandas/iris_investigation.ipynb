# %%
import pandas as pd
import numpy as np

# %%
iris = pd.read_csv('iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# iris.to_csv('filename.csv') - save iris to a csv format

# %%
iris.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Using the Iris dataset, do the following:
#
# Add a rank column to the iris DataFrame, ranking the petal length in an ascending order
# Find the mean of each column for each species
# Create a new DataFrame for each of the species separately - should have 3 in total, make sure each index starts at 0
# Create two final DataFrames: One for the Sepal information, and one for the Petal information. This should be done on the whole dataset so that in each DataFrame we have information about all three species

# %%
iris['petal_length'].rank(ascending=True)
# Out:
# 0       17.5
# 1       17.5
# 2        8.0
# 3       30.5
# 4       17.5
#        ...
# 145    117.5
# 146    106.5
# 147    117.5
# 148    121.5
# 149    112.5
# Name: petal_length, Length: 150, dtype: float64

# %%
iris['rank'] = iris['petal_length'].rank(ascending=True)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species   rank
# 0             5.1          3.5           1.4          0.2     setosa   17.5
# 1             4.9          3.0           1.4          0.2     setosa   17.5
# 2             4.7          3.2           1.3          0.2     setosa    8.0
# 3             4.6          3.1           1.5          0.2     setosa   30.5
# 4             5.0          3.6           1.4          0.2     setosa   17.5
# ..            ...          ...           ...          ...        ...    ...
# 145           6.7          3.0           5.2          2.3  virginica  117.5
# 146           6.3          2.5           5.0          1.9  virginica  106.5
# 147           6.5          3.0           5.2          2.0  virginica  117.5
# 148           6.2          3.4           5.4          2.3  virginica  121.5
# 149           5.9          3.0           5.1          1.8  virginica  112.5
#
# [150 rows x 6 columns]

# %%
iris.groupby(['species']).mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width    rank
# species
# setosa             5.006        3.418         1.464        0.244   25.50
# versicolor         5.936        2.770         4.260        1.326   76.39
# virginica          6.588        2.974         5.552        2.026  124.61

# %%
spec = iris.groupby('species')

# %%
spec

# %%
spec.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species   rank
# 0             5.1          3.5           1.4          0.2      setosa   17.5
# 1             4.9          3.0           1.4          0.2      setosa   17.5
# 2             4.7          3.2           1.3          0.2      setosa    8.0
# 3             4.6          3.1           1.5          0.2      setosa   30.5
# 4             5.0          3.6           1.4          0.2      setosa   17.5
# 50            7.0          3.2           4.7          1.4  versicolor   93.0
# 51            6.4          3.2           4.5          1.5  versicolor   83.5
# 52            6.9          3.1           4.9          1.5  versicolor  102.0
# 53            5.5          2.3           4.0          1.3  versicolor   64.0
# 54            6.5          2.8           4.6          1.5  versicolor   89.0
# 100           6.3          3.3           6.0          2.5   virginica  140.5
# 101           5.8          2.7           5.1          1.9   virginica  112.5
# 102           7.1          3.0           5.9          2.1   virginica  138.5
# 103           6.3          2.9           5.6          1.8   virginica  128.5
# 104           6.5          3.0           5.8          2.2   virginica  136.0

# %%
spec.describe()
# Out:
#            sepal_length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# species
# setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal_width         ... petal_width       rank                     \
#                  count   mean  ...         75%  max count    mean        std
# species                        ...
# setosa            50.0  3.418  ...         0.3  0.6  50.0   25.50  14.271421
# versicolor        50.0  2.770  ...         1.5  1.8  50.0   76.39  15.901896
# virginica         50.0  2.974  ...         2.3  2.5  50.0  124.61  16.058023
#
#
#              min    25%     50%      75%    max
# species
# setosa       1.0   17.5   30.50   38.375   49.5
# versicolor  51.0   64.0   76.00   89.000  112.5
# virginica   83.5  112.5  126.25  137.875  150.0
#
# [3 rows x 40 columns]

# %%
spec.mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width    rank
# species
# setosa             5.006        3.418         1.464        0.244   25.50
# versicolor         5.936        2.770         4.260        1.326   76.39
# virginica          6.588        2.974         5.552        2.026  124.61

# %%
iris.groupby('species').mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width    rank
# species
# setosa             5.006        3.418         1.464        0.244   25.50
# versicolor         5.936        2.770         4.260        1.326   76.39
# virginica          6.588        2.974         5.552        2.026  124.61

# %%
setosa = iris[iris['species'] == 'setosa']
versicolor = iris[iris['species'] == 'versicolor'].reset_index()
virginica = iris[iris['species'] == 'virginica'].reset_index()

# %%
setosa.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  rank
# 0           5.1          3.5           1.4          0.2  setosa  17.5
# 1           4.9          3.0           1.4          0.2  setosa  17.5
# 2           4.7          3.2           1.3          0.2  setosa   8.0
# 3           4.6          3.1           1.5          0.2  setosa  30.5
# 4           5.0          3.6           1.4          0.2  setosa  17.5

# %%
sepal = iris[['sepal_length', 'sepal_width', 'species']]
petal = iris[['petal_length', 'petal_width', 'species']]

# %%
sepal.head()
# Out:
#    sepal_length  sepal_width species
# 0           5.1          3.5  setosa
# 1           4.9          3.0  setosa
# 2           4.7          3.2  setosa
# 3           4.6          3.1  setosa
# 4           5.0          3.6  setosa

# %%
petal.head()
# Out:
#    petal_length  petal_width species
# 0           1.4          0.2  setosa
# 1           1.4          0.2  setosa
# 2           1.3          0.2  setosa
# 3           1.5          0.2  setosa
# 4           1.4          0.2  setosa

# %% [markdown]
# # Merging

# %%
pd.merge(sepal, petal, how='inner', right_index=True, left_index=True)
# Out:
#      sepal_length  sepal_width  species_x  petal_length  petal_width  \
# 0             5.1          3.5     setosa           1.4          0.2
# 1             4.9          3.0     setosa           1.4          0.2
# 2             4.7          3.2     setosa           1.3          0.2
# 3             4.6          3.1     setosa           1.5          0.2
# 4             5.0          3.6     setosa           1.4          0.2
# ..            ...          ...        ...           ...          ...
# 145           6.7          3.0  virginica           5.2          2.3
# 146           6.3          2.5  virginica           5.0          1.9
# 147           6.5          3.0  virginica           5.2          2.0
# 148           6.2          3.4  virginica           5.4          2.3
# 149           5.9          3.0  virginica           5.1          1.8
#
#      species_y
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 6 columns]

# %%
sepal['sepal_id'] = np.arange(150)
petal['petal_id'] = np.arange(150)
sepal.tail()
# Out:
# C:\Users\harry\AppData\Local\Temp\ipykernel_3836\1318985142.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sepal['sepal_id'] = np.arange(150)
# C:\Users\harry\AppData\Local\Temp\ipykernel_3836\1318985142.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   petal['petal_id'] = np.arange(150)
#      sepal_length  sepal_width    species  sepal_id
# 145           6.7          3.0  virginica       145
# 146           6.3          2.5  virginica       146
# 147           6.5          3.0  virginica       147
# 148           6.2          3.4  virginica       148
# 149           5.9          3.0  virginica       149

# %%
pd.merge(sepal, petal, left_on='sepal_id', right_on='petal_id')
# Out:
#      sepal_length  sepal_width  species_x  sepal_id  petal_length  \
# 0             5.1          3.5     setosa         0           1.4
# 1             4.9          3.0     setosa         1           1.4
# 2             4.7          3.2     setosa         2           1.3
# 3             4.6          3.1     setosa         3           1.5
# 4             5.0          3.6     setosa         4           1.4
# ..            ...          ...        ...       ...           ...
# 145           6.7          3.0  virginica       145           5.2
# 146           6.3          2.5  virginica       146           5.0
# 147           6.5          3.0  virginica       147           5.2
# 148           6.2          3.4  virginica       148           5.4
# 149           5.9          3.0  virginica       149           5.1
#
#      petal_width  species_y  petal_id
# 0            0.2     setosa         0
# 1            0.2     setosa         1
# 2            0.2     setosa         2
# 3            0.2     setosa         3
# 4            0.2     setosa         4
# ..           ...        ...       ...
# 145          2.3  virginica       145
# 146          1.9  virginica       146
# 147          2.0  virginica       147
# 148          2.3  virginica       148
# 149          1.8  virginica       149
#
# [150 rows x 8 columns]

# %%
pd.concat([versicolor, setosa], axis=0)
# Out:
#     index  sepal_length  sepal_width  petal_length  petal_width     species  \
# 0    50.0           7.0          3.2           4.7          1.4  versicolor
# 1    51.0           6.4          3.2           4.5          1.5  versicolor
# 2    52.0           6.9          3.1           4.9          1.5  versicolor
# 3    53.0           5.5          2.3           4.0          1.3  versicolor
# 4    54.0           6.5          2.8           4.6          1.5  versicolor
# ..    ...           ...          ...           ...          ...         ...
# 45    NaN           4.8          3.0           1.4          0.3      setosa
# 46    NaN           5.1          3.8           1.6          0.2      setosa
# 47    NaN           4.6          3.2           1.4          0.2      setosa
# 48    NaN           5.3          3.7           1.5          0.2      setosa
# 49    NaN           5.0          3.3           1.4          0.2      setosa
#
#      rank
# 0    93.0
# 1    83.5
# 2   102.0
# 3    64.0
# 4    89.0
# ..    ...
# 45   17.5
# 46   41.0
# 47   17.5
# 48   30.5
# 49   17.5
#
# [100 rows x 7 columns]

# %%
import seaborn as sns

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_pivot = flights.pivot('year', 'month', 'passengers')
flights_pivot
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(flights_pivot)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
flights_stack = flights_pivot.stack()
flights_stack
# Out:
# year  month
# 1949  Jan      112
#       Feb      118
#       Mar      132
#       Apr      129
#       May      121
#               ...
# 1960  Aug      606
#       Sep      508
#       Oct      461
#       Nov      390
#       Dec      432
# Length: 144, dtype: int64

# %%
flights_stack[1955, 'Apr']
# Out:
# 269

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']
